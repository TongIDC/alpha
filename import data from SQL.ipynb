# %%
from sqlalchemy import create_engine
import pymysql
import pandas as pd

# %%
print(f'pymysql version: {pymysql.__version__}')
print(f'pandas version: {pd.__version__}')
# Out:
# pymysql version: 0.9.3
# pandas version: 0.23.4

# %%
uid='root'
#pwd='relational'
host='localhost'
port=3306
db='test'
con_string=f'mysql+pymysql://{uid}@{host}:{port}/{db}'
#con_string=f'mysql+pymysql://{uid}:{pwd}@{host}:{port}/{db}'
print(f'connection string = {con_string}')
con=create_engine(con_string)
# con = create_engine('mysql+pymysql://guest:relational@relational.fit.cvut.cz:3306/imdb_small')
# Out:
# connection string = mysql+pymysql://root@localhost:3306/test

# %%
con.table_names()
# Out:
# ['2018_11_01', '2019-03-26']

# %%
r = con.execute("select * from 2018_11_01 limit 5;").fetchall()
r #list
# Out:
# [(1, 'PHP Programming', 'สมชาย', 250),
#  (2, 'Java Programming', 'สมชาย', 900),
#  (3, 'SQL Programming', 'สมหญิง', 850),
#  (4, 'JavaScript Programming', 'สมชาติ', 300),
#  (5, 'Python Programming', 'สมศักดิ์', 1220)]

# %%
sql = "select * from 2018_11_01;"
df = pd.read_sql(sql, con)
df #dataframe
# Out:
#     id                 Time  Generation  Consumption  Charge  \
# 0    0  2018-11-01 00:15:00           0         1615       0
# 1    1  2018-11-01 00:30:00           0         1934       0
# 2    2  2018-11-01 00:45:00           0         1655       0
# 3    3  2018-11-01 01:00:00           0         1512       0
# 4    4  2018-11-01 01:15:00           0         1871       0
# 5    5  2018-11-01 01:30:00           0         1563       0
# 6    6  2018-11-01 01:45:00           0         1522       0
# 7    7  2018-11-01 02:00:00           0         1293       0
# 8    8  2018-11-01 02:15:00           0         1685       0
# 9    9  2018-11-01 02:30:00           0         1480       0
# 10  10  2018-11-01 02:45:00           0         1494       0
# 11  11  2018-11-01 03:00:00           0         1402       0
# 12  12  2018-11-01 03:15:00           0         1368       0
# 13  13  2018-11-01 03:30:00           0         1388       0
# 14  14  2018-11-01 03:45:00           0          914       0
# 15  15  2018-11-01 04:00:00           0          811       0
# 16  16  2018-11-01 04:15:00           0         1302       0
# 17  17  2018-11-01 04:30:00           0         1225       0
# 18  18  2018-11-01 04:45:00           0         1050       0
# 19  19  2018-11-01 05:00:00           0         2777       0
# 20  20  2018-11-01 05:15:00           0         1437       0
# 21  21  2018-11-01 05:30:00           0         3332       0
# 22  22  2018-11-01 05:45:00           0         1082       0
# 23  23  2018-11-01 06:00:00           0          775       0
# 24  24  2018-11-01 06:15:00           0          829       0
# 25  25  2018-11-01 06:30:00           2         1587       0
# 26  26  2018-11-01 06:45:00          62          721       0
# 27  27  2018-11-01 07:00:00         156          716       0
# 28  28  2018-11-01 07:15:00         301          898       0
# 29  29  2018-11-01 07:30:00         592          854       0
# 29                  262          1          0                         262
# ..                  ...        ...        ...                         ...
# 66                  658          0          0                         658
# 67                 1033          0          0                        1033
# 68                 1916          0          0                        1916
# 69                 1485          0          0                        1485
# 70                 2132          0          0                        2132
# 71                 1948          0          0                        1948
# 72                 2103          0          0                        2103
# 73                 1991          0          0                        1991
# 74                 3479          0          0                        3479
# 75                 2139          0          0                        2139
# 76                 3133          0          0                        3133
# 77                 2214          0          0                        2214
# 78                 2139          0          0                        2139
# 79                 3086          0          0                        3086
# 80                 2882          0          0                        2882
# 81                 4512          0          0                        4512
# 82                 2559          0          0                        2559
# 83                 3040          0          0                        3040
# 84                 3018          0          0                        3018
# 85                 2173          0          0                        2173
# 86                 2229          0          0                        2229
# 87                 3210          0          0                        3210
# 88                 3700          0          0                        3700
# 89                 2961          0          0                        2961
# 90                 2792          0          0                        2792
# 91                 2252          0          0                        2252
# 92                 1670          0          0                        1670
# 93                 1804          0          0                        1804
# 94                 1789          0          0                        1789
# 95                 1769          0          0                        1769
#
# [96 rows x 9 columns]

# %%
sql = """
    select year, count(id) as cnt 
        from movies 
        group by year 
        order by cnt desc 
        limit 5
"""
df = pd.read_sql(sql, con)
df
# Out:
#    year  cnt
# 0  1999    4
# 1  2000    4
# 2  2003    4
# 3  2001    3
# 4  1994    2

# %%
sql = """
    select * 
        from movies 
        where rank > %s 
        order by rank desc 
        limit 5
"""
#%s = params
df = pd.read_sql(sql, con, params=[8])
df
# Out:
#        id                       name  year  rank
# 0  297838  Shawshank Redemption, The  1994   9.0
# 1  130128             Godfather, The  1972   9.0
# 2  313459                  Star Wars  1977   8.8
# 3  210511                    Memento  2000   8.7
# 4  267038               Pulp Fiction  1994   8.7

# %%
sql = """
    select * 
        from movies 
        where rank > %s and year > %s
        order by rank desc 
        limit 5
"""
df = pd.read_sql(sql, con, params=[8, 2000])
df
# Out:
#        id               name  year  rank
# 0  176711  Kill Bill: Vol. 1  2003   8.4
# 1  124110       Garden State  2004   8.3
# 2  176712  Kill Bill: Vol. 2  2004   8.2
# 3  224842       Mystic River  2003   8.1
# 4  300229              Shrek  2001   8.1

# %%
sql = """
    select * 
        from movies 
        where rank > 8 and year > 2000
        order by rank desc 
        limit 5
"""
df = pd.read_sql(sql, con)
df
# Out:
#        id               name  year  rank
# 0  176711  Kill Bill: Vol. 1  2003   8.4
# 1  124110       Garden State  2004   8.3
# 2  176712  Kill Bill: Vol. 2  2004   8.2
# 3  224842       Mystic River  2003   8.1
# 4  300229              Shrek  2001   8.1

# %%
sql =
