# %%
import pandas as pd

# %%
files = "tongsdata/01-11-2018.json"
df = pd.read_json(files)
df
# Out:
#                                          2019-02-21 00:00:00  \
# currently  {'time': 1541005200, 'summary': 'Clear', 'icon...
# daily      {'data': [{'time': 1541005200, 'summary': 'Cle...
# flags      {'sources': ['cmc', 'gfs', 'icon', 'isd', 'mad...
# hourly     {'summary': 'Clear throughout the day.', 'icon...
# latitude                                             13.8282
# longitude                                            100.614
# offset                                                     7
# timezone                                        Asia/Bangkok
#
#                                          2019-02-21 00:15:00  \
# currently  {'time': 1541006100, 'summary': 'Clear', 'icon...
# daily      {'data': [{'time': 1541005200, 'summary': 'Cle...
# flags      {'sources': ['cmc', 'gfs', 'icon', 'isd', 'mad...
# hourly     {'summary': 'Clear throughout the day.', 'icon...
# latitude                                             13.8282
# ...
