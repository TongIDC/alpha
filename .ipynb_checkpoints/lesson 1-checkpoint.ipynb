# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv(r"C:\Users\User\Desktop\Data\Energy_Balance_2018_11_01.csv", sep=';' , usecols=[0,8])
df
# Out:
#               PV power generation / Mean values [W]
# 0    ="00:00"
# 1    ="00:15"                                     NaN
# 2    ="00:30"                                     NaN
# 3    ="00:45"                                     NaN
# 4    ="01:00"                                     NaN
# 5    ="01:15"                                     NaN
# 6    ="01:30"                                     NaN
# 7    ="01:45"                                     NaN
# 8    ="02:00"                                     NaN
# 9    ="02:15"                                     NaN
# 10   ="02:30"                                     NaN
# 11   ="02:45"                                     NaN
# 12   ="03:00"                                     NaN
# 13   ="03:15"                                     NaN
# 14   ="03:30"                                     NaN
# 15   ="03:45"                                     NaN
# 16   ="04:00"                                     NaN
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 2 columns):
#                                            157 non-null object
# PV power generation / Mean values [W]      108 non-null object
# dtypes: object(2)
# memory usage: 2.5+ KB

# %%
df['PV power generation / Mean values [W]  '].replace(' ', np.nan, inplace=True)

# %%
modifieddf = df.dropna()

# %%
modifieddf.to_csv('modifiedEnergy.csv',index=False)
